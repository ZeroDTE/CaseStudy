# %% [markdown]
# # Management Summary: Süßwarensortiment-Erweiterung Lidl 🍫
#
# ## 1. Ausgangssituation & Zielsetzung 🎯
# - **Herausforderung:** Entwicklung einer neuen Eigenmarken-Süßigkeit für Lidl
# - **Ziel:** Maximierung der Marktakzeptanz durch datengetriebene Produktentwicklung
# - **Datenbasis:** Umfassende Marktforschungsdaten zu Süßigkeiten-Präferenzen
#
# ## 2. Kernerkenntnisse der Marktanalyse 📊
#
# ### A. Erfolgsfaktoren (basierend auf Korrelationsanalyse)
# 1. **Starke positive Korrelationen mit Verkaufserfolg:**
#    - Schokolade (+0.637)
#    - Riegel-Format (+0.430)
#    - Erdnuss/Mandel-Komponenten (+0.406)
#
# 2. **Negative Korrelationen:**
#    - Fruchtgeschmack (-0.381)
#    - Harte Konsistenz (-0.310)
#
# ### B. Preis-Leistungs-Analyse 💰
# - Moderate positive Korrelation zwischen Preis und Erfolg (+0.345)
# - Optimaler Preispunkt: Mittleres Segment
# - Passt zur Lidl-Positionierung
#
# ---
#
# ## 3. Strategische Empfehlung 🎯
#
# ### Produktkonzept
# Produkt: "Lidl CrispNut Bar"
# ────────────────────────────
# Kernmerkmale:
# • Schokoriegel mit Erdnuss-Crisp-Kern
# • Knusprige Textur (Rice-Crisp)
# • Vollmilchschokoladenüberzug
#
# ### SWOT-Analyse des Konzepts
#
# #### ✅ Stärken
# - Kombiniert die drei erfolgreichsten Produktmerkmale
# - Entspricht aktuellen Marktpräferenzen
# - Differenziertes Produkt im Eigenmarken-Segment
#
# #### ⚠️ Schwächen
# - Höhere Produktionskosten durch Nuss-Komponente
# - Komplexerer Herstellungsprozess
#
# #### 🌟 Chancen
# - Potenzial für Produktfamilien-Entwicklung
# - Cross-Selling mit anderen Lidl-Produkten
# - Premiumisierung der Eigenmarke
#
# #### ⚡ Risiken
# - Allergene (Nüsse)
# - Rohstoffpreisschwankungen
# - Starker Wettbewerb im Segment
#
# ---
#
# ## 4. Business Case 💼
#
# ### Kostenstruktur
# - **Optimierung durch:**
#   - Rice-Crisp als Kostendämpfer
#   - Skaleneffekte durch Eigenproduktion
#   - Effizientes Riegelformat
#
# ### Erfolgsfaktoren
# 1. **Kurzfristig:**
#    - Schnelle Markteinführung
#    - Starke POS-Präsenz
#    - Einführungspromotion
#
# 2. **Langfristig:**
#    - Qualitätskonsistenz
#    - Preispositionierung im mittleren Segment
#    - Marketing-Integration in Lidl-Kampagnen
#
# ---
#
# ## 5. KPIs & Monitoring 📈
#
# ### Erfolgsmetriken
# - 📊 Absatzzahlen
# - 📈 Marktanteil im Segment
# - 🗣️ Kundenrückmeldungen
# - 🔄 Wiederkaufrate
#
# ### Meilensteine
# | Phase | Aktivität | Zeitraum | Dauer |
# |-------|-----------|----------|--------|
# | 1️⃣ | Produktentwicklung | Q1 2024 | 90 Tage |
# | 2️⃣ | Testmarkt | Q2 2024 | 60 Tage |
# | 3️⃣ | Nationale Einführung | Q3 2024 | 90 Tage |
#
# ---
#
# ## 6. Handlungsempfehlung 📋
#
# ### 🏃 Kurzfristig
# 1. Start Produktentwicklung
# 2. Lieferantenauswahl
# 3. Marketingkonzept erstellen
#
# ### 🚶 Mittelfristig
# 1. Testmarktphase in ausgewählten Filialen
# 2. Feedback-Analyse
# 3. Produktoptimierung
#
# ### 🎯 Langfristig
# 1. Nationale Ausrollung
# 2. Produktlinien-Erweiterung
# 3. Internationale Expansion prüfen
#
# ---
#
# ## 7. Finanzieller Impact (Schätzung) 💶
#
# ### Annahmen
# - Verkaufspreis: 0,79€
# - Herstellungskosten: 0,32€
# - Marge: 59%
# - Zielabsatz Jahr 1: 5 Mio. Stück
#
# ### Erwartete Ergebnisse
# - **Jahresumsatz:** 3,95 Mio. €
# - **Deckungsbeitrag:** 2,35 Mio. €
#
# ---
#
# *Diese Analyse basiert auf den vorliegenden Marktforschungsdaten und berücksichtigt sowohl statistische als auch betriebswirtschaftliche Aspekte.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('candy-data.csv')

data.head(10)
# Out:
#        competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0           100 Grand          1       0        1               0       0
# 1        3 Musketeers          1       0        0               0       1
# 2            One dime          0       0        0               0       0
# 3         One quarter          0       0        0               0       0
# 4           Air Heads          0       1        0               0       0
# 5          Almond Joy          1       0        0               1       0
# 6           Baby Ruth          1       0        1               1       1
# 7  Boston Baked Beans          0       0        0               1       0
# 8          Candy Corn          0       0        0               0       0
# 9  Caramel Apple Pops          0       1        1               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# ...

# %%
data_copy = data.copy()
sorted_data = data_copy.sort_values(by='winpercent', ascending=False)
sorted_data.head(10)
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 52    Reese's Peanut Butter cup          1       0        0               1
# 51           Reese's Miniatures          1       0        0               1
# 79                         Twix          1       0        1               0
# 28                      Kit Kat          1       0        0               0
# 64                     Snickers          1       0        1               1
# 53               Reese's pieces          1       0        0               1
# 36                    Milky Way          1       0        1               0
# 54  Reese's stuffed with pieces          1       0        0               1
# 32          Peanut butter M&M's          1       0        0               1
# 42          Nestle Butterfinger          1       0        0               1
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# ...

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   competitorname    85 non-null     object
#  1   chocolate         85 non-null     int64
#  2   fruity            85 non-null     int64
#  3   caramel           85 non-null     int64
#  4   peanutyalmondy    85 non-null     int64
#  5   nougat            85 non-null     int64
#  6   crispedricewafer  85 non-null     int64
#  7   hard              85 non-null     int64
#  8   bar               85 non-null     int64
#  9   pluribus          85 non-null     int64
#  10  sugarpercent      85 non-null     float64
#  11  pricepercent      85 non-null     float64
#  12  winpercent        85 non-null     float64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 8.8+ KB

# %%
data_copy.describe()
# Out:
#        chocolate     fruity    caramel  peanutyalmondy     nougat  \
# count  85.000000  85.000000  85.000000       85.000000  85.000000
# mean    0.435294   0.447059   0.164706        0.164706   0.082353
# std     0.498738   0.500140   0.373116        0.373116   0.276533
# min     0.000000   0.000000   0.000000        0.000000   0.000000
# 25%     0.000000   0.000000   0.000000        0.000000   0.000000
# 50%     0.000000   0.000000   0.000000        0.000000   0.000000
# 75%     1.000000   1.000000   0.000000        0.000000   0.000000
# max     1.000000   1.000000   1.000000        1.000000   1.000000
#
#        crispedricewafer       hard        bar   pluribus  sugarpercent  \
# count         85.000000  85.000000  85.000000  85.000000     85.000000
# mean           0.082353   0.176471   0.247059   0.517647      0.478647
# std            0.276533   0.383482   0.433861   0.502654      0.282778
# min            0.000000   0.000000   0.000000   0.000000      0.011000
# ...

# %%
print(data[(data['chocolate'] == 1) & (data['peanutyalmondy'] == 1) & (data['crispedricewafer'] == 1) & (data['caramel'] == 0)])
Schokolade_Karamell = (data['chocolate'] * data['caramel']).sum()
Schokolade_Nougat = (data['chocolate'] * data['nougat']).sum()   
print(Schokolade_Karamell)
print(Schokolade_Nougat)
# Out:
# Empty DataFrame
# Columns: [competitorname, chocolate, fruity, caramel, peanutyalmondy, nougat, crispedricewafer, hard, bar, pluribus, sugarpercent, pricepercent, winpercent, chocolate_peanut, chocolate_caramel, chocolate_nougat, sugar_price, sugar_squared, price_squared]
# Index: []
# 10
# 6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate correlations between numeric features
numeric_features = ['chocolate', 'fruity', 'caramel', 'peanutyalmondy', 'nougat', 
                   'crispedricewafer', 'hard', 'bar', 'pluribus', 'sugarpercent', 
                   'pricepercent', 'winpercent']
correlation_matrix = data[numeric_features].corr()

# Create correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, 
            annot=True,
            cmap='coolwarm',
            center=0,
            fmt='.2f',
            square=True)
plt.title('Correlation Matrix of Candy Features', pad=20)
plt.tight_layout()
plt.show()

# Feature correlations with win percentage (horizontal bar plot)
correlations = correlation_matrix['winpercent'].sort_values(ascending=True)
correlations = correlations.drop('winpercent')  # Remove self-correlation

# Create a DataFrame for seaborn to plot
corr_df = pd.DataFrame({'features': correlations.index, 'correlation': correlations.values})
plt.figure(figsize=(10, 6))
sns.barplot(data=corr_df, 
           y='features', 
           x='correlation',
           palette=['red' if x < 0 else 'green' for x in correlations.values])
plt.title('Feature Correlations with Win Percentage')
plt.axvline(x=0, color='black', linestyle='-', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Calculate and display summary statistics
print("\nCorrelations with Win Percentage:")
for feature, corr in correlations.items():
    print(f"{feature}: {corr:.3f}")

# Group candies by sugar content
data['sugar_level'] = pd.qcut(data['sugarpercent'], q=3, labels=['Low', 'Medium', 'High'])
avg_metrics = data.groupby('sugar_level')[['pricepercent', 'winpercent']].mean()

print("\nAverage metrics by sugar content level:")
print(avg_metrics)

# Create pie chart of sugar level distribution
sugar_count = data['sugar_level'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(sugar_count.values,
        labels=sugar_count.index,
        autopct='%1.1f%%',
        colors=['lightgreen', 'lightyellow', 'lightcoral'],
        explode=(0.1, 0, 0))
plt.title('Distribution of Candy by Sugar Content Level')
plt.show()
# Out:
# C:\Users\yahya\AppData\Local\Temp\ipykernel_203480\2835486814.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=corr_df,
# Correlations with Win Percentage:
# fruity: -0.381
# hard: -0.310
# pluribus: -0.247
# nougat: 0.199
# caramel: 0.213
# sugarpercent: 0.229
# crispedricewafer: 0.325
# pricepercent: 0.345
# peanutyalmondy: 0.406
# bar: 0.430
# chocolate: 0.637
#
# Average metrics by sugar content level:
#              pricepercent  winpercent
# sugar_level
# Low              0.341500   45.826091
# Medium           0.590037   54.113206
# High             0.513042   52.407553
# ...
